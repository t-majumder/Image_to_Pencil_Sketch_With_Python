# %% [markdown]
# # Image to Pencil Sketch Using Python
# ## by- Tamal Majumder
# * [LINKEDIN](https://www.linkedin.com/in/tamal-majumder-4979781a3/)
# * [GITHUB](https://github.com/t-majumder)
# ## Explanation:
# * First we load the Image in python.
# * Then just converted the image to grayscale, Invert thr Image , Apply Gaussian Blur to the Image to smooth it out.
# * Finally Converted the image to a Pencil Sketch

# %%
import cv2
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# ### Importing The Image

# %%
img=cv2.imread('D:\\Data science and ml projects\\4.Image\\cat.jpg',0)
display.Image("D:\\Data science and ml projects\\4.Image\\cat.jpg",width=250)

# %%
#Color value just for own sake
print('Minimum color range',img.min())
print('Maximum color range',img.max())
# Out:
# Minimum color range 0
# Maximum color range 255

# %% [markdown]
# ### Converting image to greyscale

# %%
#Converting image to greyscale
plt.imshow(img,cmap='gray')
plt.title('Black and white imege')
plt.show()

# %% [markdown]
# ### Inverting the image

# %%
#Inverting the image
inv=255-img
plt.title('Inverted imege')
plt.imshow(inv,cmap='gray')
plt.show()

# %% [markdown]
# ### Applying Gaussian blur to smooth out the image

# %%
#Applying Gaussian blur to smooth out the image
gblur=cv2.GaussianBlur(inv,ksize=(21,21),sigmaX=0,sigmaY=0)
plt.title('Imege after Gaussian blur applied')
plt.imshow(gblur,cmap='gray')
plt.show()

# %% [markdown]
# ### Color Dodging and burning (Final pencil sketch output)

# %%
#Color Dodging and burning (Final pencil sketch output)
dodge= lambda image,mask: cv2.divide(image,255-mask,scale=256)
blended=dodge(img,gblur)
plt.title('Pencil sketch of image')
plt.imshow(blended,cmap='gray')
plt.show()
